# %% [markdown]
# <a href="https://informatics.msk.ru/mod/statements/view.php?id=2296" style="font-size: 20px">Input/Output, Assignment Operators</a>

# %%
# Problem A
import math

a, b = map(int, input().split())
print(math.sqrt(a*a + b*b))
# Out:
# 5.0

# %%
# Problem B
num = int(input())

print(f"The next number for the number {num} is {num + 1}.")
print(f"The previous number for the number {num} is {num - 1}.")
# Out:
# The next number for the number 179 is 180.
# The previous number for the number 179 is 178.

# %%
# Problem C
a, b = map(int, input().split())
print(b // a)
# Out:
# 4

# %%
# Problem D
a, b = map(int, input().split())
print(b % a)
# Out:
# 2

# %%
# Problem E
a, b = map(int, input().split())
print(abs((abs(a) * b) - 109))
# Out:
# 11
